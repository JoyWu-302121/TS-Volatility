# %% [markdown]
# # SPX one-minute volatility: initial baselines
#
# This notebook is a thin, reproducible entry point for the script-based workflow. It evaluates only the Validation targets and does not unlock Final OOS.

# %%
from pathlib import Path

ROOT = Path.cwd().resolve().parents[1]
EXTENSION = ROOT / 'extensions'
ROOT

# %%
# Run from extensions/code with the project virtual environment active.
# !python ../scripts/build_1min_daily_rv.py
# !python ../scripts/build_features_and_splits.py
# !python ../scripts/run_baseline_models.py --window 756 --refit-every 5
# !python ../scripts/evaluate_forecasts.py

# %%
import pandas as pd

pd.read_csv(EXTENSION / 'data/processed/validation_metrics.csv').sort_values('qlike')
